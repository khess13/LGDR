# %%
import pandas as pd
junk_data_wvals = {	'Sage Automotive Interiors' : 343,
					'Flexible Technologies' 	: 296,
					'Prysmian Cable Systems' 	: 215,
				  'Burnstein Precision Casting' : 182,
					'Pro Towels' 				: 83
					}

import numpy as np

# %%
dflist = {}
xlfile = pd.read_excel('/Users/kellyhess/LGDR/CountyStatData/laucnty17.xlsx')

xlfile = xlfile.iloc[5:,[1,3,6,7,8,9]].dropna()
xlfile = xlfile[xlfile.iloc[:,0] == '45']
xlfile = xlfile.drop(['Unnamed: 1'], axis  = 1)
xlfile.columns = ['County','LaborForce','Employed','Unemployed',
                              'Rate']
xlfile = xlfile.replace({'County': r' County, SC'},{'County' : ''}, regex =  True)
xlfile
# Out:
#             County LaborForce Employed Unemployed Rate
# 2320     Abbeville      10103     9640        463  4.6
# 2321         Aiken      74442    71386       3056  4.1
# 2322     Allendale       2741     2553        188  6.9
# 2323      Anderson      89559    86045       3514  3.9
# 2324       Bamberg       5230     4842        388  7.4
# 2325      Barnwell       8082     7594        488    6
# 2326      Beaufort      74104    71113       2991    4
# 2327      Berkeley      98452    94691       3761  3.8
# 2328       Calhoun       6848     6493        355  5.2
# 2329    Charleston     204937   197802       7135  3.5
# 2330      Cherokee      24094    22909       1185  4.9
# 2331       Chester      13592    12776        816    6
# 2332  Chesterfield      21621    20680        941  4.4
# 2333     Clarendon      12425    11683        742    6
# 2334      Colleton      16844    16036        808  4.8
# 2335    Darlington      29830    28247       1583  5.3
# ...

# %%
dflist['test'] = xlfile
dflist['test2'] = 'some file'

# %%
for key, val in dflist.iteritems():
    print key
    print val
# Out:
# test
#             County LaborForce Employed Unemployed Rate
# 2320     Abbeville      10103     9640        463  4.6
# 2321         Aiken      74442    71386       3056  4.1
# 2322     Allendale       2741     2553        188  6.9
# 2323      Anderson      89559    86045       3514  3.9
# 2324       Bamberg       5230     4842        388  7.4
# 2325      Barnwell       8082     7594        488    6
# 2326      Beaufort      74104    71113       2991    4
# 2327      Berkeley      98452    94691       3761  3.8
# 2328       Calhoun       6848     6493        355  5.2
# 2329    Charleston     204937   197802       7135  3.5
# 2330      Cherokee      24094    22909       1185  4.9
# 2331       Chester      13592    12776        816    6
# 2332  Chesterfield      21621    20680        941  4.4
# 2333     Clarendon      12425    11683        742    6
# 2334      Colleton      16844    16036        808  4.8
# 2335    Darlington      29830    28247       1583  5.3
# ...
